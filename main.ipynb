# %%
import os
import types
from openai import OpenAI
from langchain_openai import ChatOpenAI

openai = ChatOpenAI(model_name="gpt-5.5")

response = openai.invoke("How much is the addition of 1 and 2?")
print(response.content)
# Out:
# 1 + 2 = 3
